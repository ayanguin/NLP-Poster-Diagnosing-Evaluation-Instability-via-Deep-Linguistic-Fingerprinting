# %%
pip install datasets polars elfen spacy
# Out:
# ...
#   Using cached polars-1.43.2-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached elfen-1.0.6-py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached polars_runtime_32-1.43.2-cp310-abi3-macosx_11_0_arm64.whl.metadata (1.5 kB)
# ...
#   Using cached polars-1.10.0-cp39-abi3-macosx_11_0_arm64.whl.metadata (14 kB)
# ...
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.2/28.2 MB 2.4 MB/s  0:00:11m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 2.8 MB/s  0:00:02m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 1.2 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.7/13.7 MB 3.1 MB/s  0:00:04m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/23.1 MB 3.3 MB/s eta 0:00:05ERROR: Could not install packages due to an OSError: [Errno 28] No space left on device
#
#    ━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/23.1 MB 3.3 MB/s eta 0:00:05
# ...
